# %%
# !git clone https://github.com/ultralytics/ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 7497, done.
# remote: Counting objects: 100% (1102/1102), done.
# remote: Compressing objects: 100% (646/646), done.
# remote: Total 7497 (delta 624), reused 765 (delta 449), pack-reused 6395
# Receiving objects: 100% (7497/7497), 5.75 MiB | 18.80 MiB/s, done.
# Resolving deltas: 100% (4975/4975), done.

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.1/562.1 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.7/201.7 kB 13.7 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="z8wphUFYxIFliMZdHK21")
project = rf.workspace("miniproject-cosdz").project("pothole-detection-system-edqhi")
dataset = project.version(2).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.6 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=12115e8a5be84475c7c910e55c21b33d42f43eecd4ed500811c89bfe41d65275
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.yaml data=/content/Pothole-Detection-System-2/data.yaml epochs=110 lr0=0.01
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
# ...

# %%
# !yolo detect predict model=/content/runs/detect/train/weights/best.pt source='/content/potholes vit.mp4'
# Out:
# Ultralytics YOLOv8.0.92 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/1394) /content/potholes vit.mp4: 640x352 (no detections), 56.8ms
# video 1/1 (2/1394) /content/potholes vit.mp4: 640x352 (no detections), 5.5ms
# video 1/1 (3/1394) /content/potholes vit.mp4: 640x352 (no detections), 5.5ms
# video 1/1 (4/1394) /content/potholes vit.mp4: 640x352 (no detections), 5.5ms
# video 1/1 (5/1394) /content/potholes vit.mp4: 640x352 1 2, 5.5ms
# video 1/1 (6/1394) /content/potholes vit.mp4: 640x352 1 2, 5.5ms
# video 1/1 (7/1394) /content/potholes vit.mp4: 640x352 1 2, 5.8ms
# video 1/1 (8/1394) /content/potholes vit.mp4: 640x352 1 2, 5.5ms
# video 1/1 (9/1394) /content/potholes vit.mp4: 640x352 1 2, 5.5ms
# video 1/1 (10/1394) /content/potholes vit.mp4: 640x352 1 2, 5.5ms
# video 1/1 (11/1394) /content/potholes vit.mp4: 640x352 1 2, 5.6ms
# ...
